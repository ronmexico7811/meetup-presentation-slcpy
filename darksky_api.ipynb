# %%
import requests 
import json
import pandas as pd
from datetime import datetime
import numpy as np

# redding_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/40.58759,-122.39261,2017-01-01T08:00:00?exclude=currently,hourly,flags')
# sacroment_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/38.57933,-121.4909,2017-01-01T08:00:00?exclude=currently,hourly,flags')
# fresno_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/36.74066,-119.78576,2017-01-01T08:00:00?exclude=currently,hourly,flags')
# bakersfield_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/35.36723,-119.01886,2017-01-01T08:00:00?exclude=currently,hourly,flags')
# san_diego_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/32.715,-117.1625,2017-01-01T08:00:00?exclude=currently,hourly,flags')

# %%
#redding-good 
dti = pd.date_range('2015-07-02', periods=1279, freq='d')

redding_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/40.58759,-122.39261,2015-07-01T08:00:00?exclude=currently,hourly,flags')
# print(redding_request)
redding_request_j = redding_request.content.decode("utf-8")
# print(redding_request_j)
redding_request_d = json.loads(redding_request_j)
# print(redding_request_d)
dw = redding_request_d["daily"]['data']
df_redding = pd.DataFrame(dw)
# print(df_redding)

for d in dti:
    d = str(d)
    d = d.replace('00:00:00','').strip()
    redding_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/40.58759,-122.39261,' + d + 'T08:00:00?exclude=currently,hourly,flags')
#     print(redding_request)
    redding_request_j = redding_request.content.decode("utf-8")
    redding_request_d = json.loads(redding_request_j)
    dw = redding_request_d["daily"]['data']
    df2 = pd.DataFrame(dw)
#     print(df2)
    df_redding = pd.concat([df_redding, df2], sort = True)

df_redding.reset_index(inplace = True, drop = True)
df_redding['time'] = df_redding['time'].map(lambda x: datetime.utcfromtimestamp(x).strftime('%m-%d-%Y'))
df_redding = df_redding.set_index('time')

df_redding.head()
# Out:
#             apparentTemperatureHigh  apparentTemperatureHighTime  \
# time
# 07-01-2015                   109.08                 1.435788e+09
# 07-02-2015                   105.65                 1.435882e+09
# 07-03-2015                    99.65                 1.435964e+09
# 07-04-2015                   104.44                 1.436051e+09
# 07-05-2015                   101.12                 1.436137e+09
#
#             apparentTemperatureLow  apparentTemperatureLowTime  \
# time
# 07-01-2015                   76.32                1.435842e+09
# 07-02-2015                   78.75                1.435932e+09
# 07-03-2015                   74.08                1.436015e+09
# 07-04-2015                   76.92                1.436105e+09
# 07-05-2015                   71.48                1.436191e+09
#
#             apparentTemperatureMax  apparentTemperatureMaxTime  \
# time
# 07-01-2015                  109.08                  1435788000
# ...

# %%
df_redding_trim = df_redding[['apparentTemperatureHigh',
                             'apparentTemperatureLow', 
                             'apparentTemperatureMax', 
                             'apparentTemperatureMin', 
                             'cloudCover',
                             'dewPoint', 
                             'humidity', 
                             'icon', 
                             'moonPhase', 
                             'precipIntensity',
                             'precipIntensityMax', 
                             'precipProbability', 
                             'pressure', 
                             'summary',
                             'sunriseTime', 
                             'sunsetTime', 
                             'temperatureHigh', 
                             'temperatureLow',
                             'temperatureMax',
                             'temperatureMin', 
                             'uvIndex',
                             'visibility', 
                             'windBearing',
                             'windGust',
                             'windSpeed']]
df_redding_trim.tail()
# Out:
#             apparentTemperatureHigh  apparentTemperatureLow  \
# time
# 12-27-2018                    55.58                   35.26
# 12-28-2018                    56.46                   40.84
# 12-29-2018                    62.34                   37.12
# 12-30-2018                    56.79                   36.71
# 12-31-2018                    52.49                   35.34
#
#             apparentTemperatureMax  apparentTemperatureMin  cloudCover  \
# time
# 12-27-2018                   55.58                   38.36        0.05
# 12-28-2018                   56.46                   35.26        0.05
# 12-29-2018                   62.34                   40.84        0.01
# 12-30-2018                   56.79                   37.12        0.01
# 12-31-2018                   52.49                   36.71        0.00
#
#             dewPoint  humidity               icon  moonPhase  precipIntensity  \
# time
# ...

# %%
#sacroment-good
sacroment_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/38.57933,-121.4909,2015-07-01T08:00:00?exclude=currently,hourly,flags')
# print(sacroment_request)
sacroment_request_j = sacroment_request.content.decode("utf-8")
# print(sacroment_request_j)
sacroment_request_d = json.loads(sacroment_request_j)
# print(sacroment_request_d)
dw = sacroment_request_d["daily"]['data']
df_sacroment = pd.DataFrame(dw)
# print(df_sacroment)

for d in dti:
    d = str(d)
    d = d.replace('00:00:00','').strip()
    sacroment_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/38.57933,-121.4909,' + d + 'T08:00:00?exclude=currently,hourly,flags')
#     print(redding_request)
    sacroment_request_j = sacroment_request.content.decode("utf-8")
    sacroment_request_d = json.loads(sacroment_request_j)
    dw = sacroment_request_d["daily"]['data']
    df2 = pd.DataFrame(dw)
#     print(df2)
    df_sacroment = pd.concat([df_sacroment, df2], sort = True)

df_sacroment.reset_index(inplace = True, drop = True)
df_sacroment['time'] = df_sacroment['time'].map(lambda x: datetime.utcfromtimestamp(x).strftime('%m-%d-%Y'))
df_sacroment = df_sacroment.set_index('time')

df_sacroment.head()
# Out:
#             apparentTemperatureHigh  apparentTemperatureHighTime  \
# time
# 07-01-2015                    99.86                 1.435795e+09
# 07-02-2015                    94.56                 1.435878e+09
# 07-03-2015                    97.39                 1.435968e+09
# 07-04-2015                   101.52                 1.436051e+09
# 07-05-2015                    90.69                 1.436141e+09
#
#             apparentTemperatureLow  apparentTemperatureLowTime  \
# time
# 07-01-2015                   76.12                1.435842e+09
# 07-02-2015                   66.90                1.435932e+09
# 07-03-2015                   64.99                1.436015e+09
# 07-04-2015                   62.24                1.436101e+09
# 07-05-2015                   60.55                1.436188e+09
#
#             apparentTemperatureMax  apparentTemperatureMaxTime  \
# time
# 07-01-2015                   99.86                  1435795200
# ...

# %%
df_sacroment_trim = df_sacroment[['apparentTemperatureHigh',
                             'apparentTemperatureLow', 
                             'apparentTemperatureMax', 
                             'apparentTemperatureMin', 
                             'cloudCover',
                             'dewPoint', 
                             'humidity', 
                             'icon', 
                             'moonPhase', 
                             'precipIntensity',
                             'precipIntensityMax', 
                             'precipProbability', 
                             'pressure', 
                             'summary',
                             'sunriseTime', 
                             'sunsetTime', 
                             'temperatureHigh', 
                             'temperatureLow',
                             'temperatureMax',
                             'temperatureMin', 
                             'uvIndex',
                             'visibility', 
                             'windBearing', 
                             'windGust',
                             'windSpeed']]

df_sacroment_trim.tail()
# Out:
#             apparentTemperatureHigh  apparentTemperatureLow  \
# time
# 12-27-2018                    57.26                   35.43
# 12-28-2018                    55.76                   34.83
# 12-29-2018                    54.98                   35.25
# 12-30-2018                    56.02                   36.43
# 12-31-2018                    54.86                   32.06
#
#             apparentTemperatureMax  apparentTemperatureMin  cloudCover  \
# time
# 12-27-2018                   57.26                   35.64        0.01
# 12-28-2018                   55.76                   35.43        0.00
# 12-29-2018                   54.98                   34.83        0.01
# 12-30-2018                   56.02                   35.25        0.03
# 12-31-2018                   54.86                   36.43        0.00
#
#             dewPoint  humidity       icon  moonPhase  precipIntensity  ...  \
# time                                                                   ...
# ...

# %%
#fresno
fresno_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/36.74066,-119.78576,2015-07-01T08:00:00?exclude=currently,hourly,flags')
# print(fresno_request)
fresno_request_j = fresno_request.content.decode("utf-8")
# print(sacroment_request_j)
fresno_request_d = json.loads(fresno_request_j)
# print(sacroment_request_d)
dw = fresno_request_d["daily"]['data']
df_fresno = pd.DataFrame(dw)
# print(df_sacroment)

for d in dti:
    d = str(d)
    d = d.replace('00:00:00','').strip()
    fresno_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/36.74066,-119.78576,' + d + 'T08:00:00?exclude=currently,hourly,flags')
#     print(redding_request)
    fresno_request_j = fresno_request.content.decode("utf-8")
    fresno_request_d = json.loads(fresno_request_j)
    dw = fresno_request_d["daily"]['data']
    df2 = pd.DataFrame(dw)
#     print(df2)
    df_fresno = pd.concat([df_fresno, df2], sort = True)

df_fresno.reset_index(inplace = True, drop = True)
df_fresno['time'] = df_fresno['time'].map(lambda x: datetime.utcfromtimestamp(x).strftime('%m-%d-%Y'))
df_fresno = df_fresno.set_index('time')

df_fresno.head()
# Out:
#             apparentTemperatureHigh  apparentTemperatureHighTime  \
# time
# 07-01-2015                    99.65                 1.435799e+09
# 07-02-2015                    94.28                 1.435878e+09
# 07-03-2015                   100.55                 1.435964e+09
# 07-04-2015                   102.20                 1.436054e+09
# 07-05-2015                    96.75                 1.436141e+09
#
#             apparentTemperatureLow  apparentTemperatureLowTime  \
# time
# 07-01-2015                   78.95                1.435842e+09
# 07-02-2015                   72.67                1.435928e+09
# 07-03-2015                   73.50                1.436015e+09
# 07-04-2015                   71.54                1.436101e+09
# 07-05-2015                   68.78                1.436188e+09
#
#             apparentTemperatureMax  apparentTemperatureMaxTime  \
# time
# 07-01-2015                   99.65                  1435798800
# ...

# %%
df_fresno_trim = df_fresno[['apparentTemperatureHigh',
                             'apparentTemperatureLow', 
                             'apparentTemperatureMax', 
                             'apparentTemperatureMin', 
                             'cloudCover',
                             'dewPoint', 
                             'humidity', 
                             'icon', 
                             'moonPhase', 
                             'precipIntensity',
                             'precipIntensityMax', 
                             'precipProbability', 
                             'pressure', 
                             'summary',
                             'sunriseTime', 
                             'sunsetTime', 
                             'temperatureHigh', 
                             'temperatureLow',
                             'temperatureMax',
                             'temperatureMin', 
                             'uvIndex',
                             'visibility', 
                             'windBearing', 
                             'windGust',
                             'windSpeed']]
df_fresno_trim.tail()
# Out:
#             apparentTemperatureHigh  apparentTemperatureLow  \
# time
# 12-27-2018                    50.36                   34.91
# 12-28-2018                    52.71                   34.60
# 12-29-2018                    53.53                   34.90
# 12-30-2018                    54.23                   37.74
# 12-31-2018                    50.53                   33.01
#
#             apparentTemperatureMax  apparentTemperatureMin  cloudCover  \
# time
# 12-27-2018                   50.36                   38.06        0.40
# 12-28-2018                   52.71                   34.91        0.27
# 12-29-2018                   53.53                   34.60        0.00
# 12-30-2018                   54.23                   34.90        0.00
# 12-31-2018                   50.53                   37.74        0.40
#
#             dewPoint  humidity               icon  moonPhase  precipIntensity  \
# time
# ...

# %%
#bakersfield
bakersfield_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/35.36723,-119.01886,2015-07-01T08:00:00?exclude=currently,hourly,flags')
# print(sacroment_request)
bakersfield_request_j = bakersfield_request.content.decode("utf-8")
# print(sacroment_request_j)
bakersfield_request_d = json.loads(bakersfield_request_j)
# print(sacroment_request_d)
dw = bakersfield_request_d["daily"]['data']
df_bakersfield = pd.DataFrame(dw)
# print(df_sacroment)

for d in dti:
    d = str(d)
    d = d.replace('00:00:00','').strip()
    bakersfield_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/35.36723,-119.01886,' + d + 'T08:00:00?exclude=currently,hourly,flags')
#     print(redding_request)
    bakersfield_request_j = bakersfield_request.content.decode("utf-8")
    bakersfield_request_d = json.loads(bakersfield_request_j)
    dw = bakersfield_request_d["daily"]['data']
    df2 = pd.DataFrame(dw)
#     print(df2)
    df_bakersfield = pd.concat([df_bakersfield, df2], sort = True)

df_bakersfield.reset_index(inplace = True, drop = True)
df_bakersfield['time'] = df_bakersfield['time'].map(lambda x: datetime.utcfromtimestamp(x).strftime('%m-%d-%Y'))
df_bakersfield = df_bakersfield.set_index('time')

df_bakersfield.head()
# Out:
#             apparentTemperatureHigh  apparentTemperatureHighTime  \
# time
# 07-01-2015                   100.04                 1.435781e+09
# 07-02-2015                   100.50                 1.435874e+09
# 07-03-2015                   100.56                 1.435968e+09
# 07-04-2015                   100.86                 1.436054e+09
# 07-05-2015                    98.41                 1.436141e+09
#
#             apparentTemperatureLow  apparentTemperatureLowTime  \
# time
# 07-01-2015                   81.61                1.435842e+09
# 07-02-2015                   76.18                1.435928e+09
# 07-03-2015                   75.69                1.436015e+09
# 07-04-2015                   77.03                1.436101e+09
# 07-05-2015                   72.50                1.436188e+09
#
#             apparentTemperatureMax  apparentTemperatureMaxTime  \
# time
# 07-01-2015                  100.04                  1435780800
# ...

# %%
df_bakersfield_trim = df_bakersfield[['apparentTemperatureHigh',
                             'apparentTemperatureLow', 
                             'apparentTemperatureMax', 
                             'apparentTemperatureMin', 
                             'cloudCover',
                             'dewPoint', 
                             'humidity', 
                             'icon', 
                             'moonPhase', 
                             'precipIntensity',
                             'precipIntensityMax', 
                             'precipProbability', 
                             'pressure', 
                             'summary',
                             'sunriseTime', 
                             'sunsetTime', 
                             'temperatureHigh', 
                             'temperatureLow',
                             'temperatureMax',
                             'temperatureMin', 
                             'uvIndex',
                             'visibility', 
                             'windBearing', 
                             'windGust',
                             'windSpeed']]
df_bakersfield_trim.tail()
# Out:
#             apparentTemperatureHigh  apparentTemperatureLow  \
# time
# 12-27-2018                    48.60                   34.60
# 12-28-2018                    49.63                   34.17
# 12-29-2018                    54.62                   37.06
# 12-30-2018                    55.95                   38.08
# 12-31-2018                    48.85                   33.69
#
#             apparentTemperatureMax  apparentTemperatureMin  cloudCover  \
# time
# 12-27-2018                   48.60                   40.38        0.46
# 12-28-2018                   49.63                   34.60        0.08
# 12-29-2018                   54.62                   34.17        0.00
# 12-30-2018                   55.95                   37.06        0.00
# 12-31-2018                   48.85                   38.08        0.54
#
#             dewPoint  humidity               icon  moonPhase  precipIntensity  \
# time
# ...

# %%
#san diego
san_diego_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/32.715,-117.1625,2015-07-01T08:00:00?exclude=currently,hourly,flags')
# print(sacroment_request)
san_diego_request_j = san_diego_request.content.decode("utf-8")
# print(sacroment_request_j)
san_diego_request_d = json.loads(san_diego_request_j)
# print(sacroment_request_d)
dw = san_diego_request_d["daily"]['data']
df_san_diego = pd.DataFrame(dw)
# print(df_sacroment)

for d in dti:
    d = str(d)
    d = d.replace('00:00:00','').strip()
    san_diego_request = requests.get('https://api.darksky.net/forecast/e9d8afefcdc0cda8d0a245218ec5db96/32.715,-117.1625,' + d + 'T08:00:00?exclude=currently,hourly,flags')
#     print(san_diego_request)
    san_diego_request_j = san_diego_request.content.decode("utf-8")
    san_diego_request_d = json.loads(san_diego_request_j)
    dw = san_diego_request_d["daily"]['data']
    df2 = pd.DataFrame(dw)
#     print(df2)
    df_san_diego = pd.concat([df_san_diego, df2], sort = True)

df_san_diego.reset_index(inplace = True, drop = True)
df_san_diego['time'] = df_san_diego['time'].map(lambda x: datetime.utcfromtimestamp(x).strftime('%m-%d-%Y'))
df_san_diego = df_san_diego.set_index('time')

df_san_diego.head()
# Out:
#             apparentTemperatureHigh  apparentTemperatureHighTime  \
# time
# 07-01-2015                    87.07                 1.435781e+09
# 07-02-2015                    86.17                 1.435871e+09
# 07-03-2015                    82.64                 1.435957e+09
# 07-04-2015                    77.58                 1.436044e+09
# 07-05-2015                    74.17                 1.436134e+09
#
#             apparentTemperatureLow  apparentTemperatureLowTime  \
# time
# 07-01-2015                   69.86                1.435849e+09
# 07-02-2015                   66.92                1.435928e+09
# 07-03-2015                   67.21                1.435997e+09
# 07-04-2015                   65.32                1.436101e+09
# 07-05-2015                   65.38                1.436180e+09
#
#             apparentTemperatureMax  apparentTemperatureMaxTime  \
# time
# 07-01-2015                   87.07                  1435780800
# ...

# %%
df_san_diego_trim = df_san_diego[['apparentTemperatureHigh',
                             'apparentTemperatureLow', 
                             'apparentTemperatureMax', 
                             'apparentTemperatureMin', 
                             'cloudCover',
                             'dewPoint', 
                             'humidity', 
                             'icon', 
                             'moonPhase', 
                             'precipIntensity',
                             'precipIntensityMax', 
                             'precipProbability', 
                             'pressure', 
                             'summary',
                             'sunriseTime', 
                             'sunsetTime', 
                             'temperatureHigh', 
                             'temperatureLow',
                             'temperatureMax',
                             'temperatureMin', 
                             'uvIndex',
                             'visibility', 
                             'windBearing', 
                             'windGust',
                             'windSpeed']]
df_san_diego_trim.tail()
# Out:
#             apparentTemperatureHigh  apparentTemperatureLow  \
# time
# 12-27-2018                    62.00                   44.98
# 12-28-2018                    60.99                   42.38
# 12-29-2018                    61.09                   44.57
# 12-30-2018                    63.92                   53.66
# 12-31-2018                    58.35                   43.47
#
#             apparentTemperatureMax  apparentTemperatureMin  cloudCover  \
# time
# 12-27-2018                   62.00                   48.31        0.37
# 12-28-2018                   60.99                   44.98        0.00
# 12-29-2018                   61.09                   42.38        0.01
# 12-30-2018                   63.92                   44.57        0.17
# 12-31-2018                   58.35                   43.64        0.93
#
#             dewPoint  humidity                 icon  moonPhase  \
# time
# 12-27-2018     44.63      0.69    partly-cloudy-day       0.69
# ...

# %%
df_total = pd.concat([df_redding_trim, df_sacroment_trim], sort = True)
df_total = pd.concat([df_total, df_fresno_trim], sort = True)
df_total = pd.concat([df_total, df_bakersfield_trim], sort = True)
df_total = pd.concat([df_total, df_san_diego_trim], sort = True)

df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6400 entries, 07-01-2015 to 12-31-2018
# Data columns (total 25 columns):
# apparentTemperatureHigh    6395 non-null float64
# apparentTemperatureLow     6395 non-null float64
# apparentTemperatureMax     6400 non-null float64
# apparentTemperatureMin     6400 non-null float64
# cloudCover                 6400 non-null float64
# dewPoint                   6400 non-null float64
# humidity                   6400 non-null float64
# icon                       6400 non-null object
# moonPhase                  6400 non-null float64
# precipIntensity            6400 non-null float64
# precipIntensityMax         6400 non-null float64
# precipProbability          6400 non-null float64
# pressure                   6400 non-null float64
# summary                    6400 non-null object
# sunriseTime                6400 non-null int64
# sunsetTime                 6400 non-null int64
# temperatureHigh            6395 non-null float64
# ...

# %%
df_group = df_total.groupby("time")
df_group.groups
df_mean = df_group.agg(np.mean)
# df_mean.reindex(inplace = True, drop = True)
df_mean.head()
# Out:
#             apparentTemperatureHigh  apparentTemperatureLow  \
# time
# 01-01-2016                   53.216                  38.102
# 01-01-2017                   52.314                  41.958
# 01-01-2018                   66.468                  45.264
# 01-02-2016                   53.704                  41.892
# 01-02-2017                   49.548                  42.752
#
#             apparentTemperatureMax  apparentTemperatureMin  cloudCover  \
# time
# 01-01-2016                  53.216                  34.786       0.176
# 01-01-2017                  52.314                  40.050       0.708
# 01-01-2018                  66.468                  42.550       0.308
# 01-02-2016                  53.704                  38.374       0.344
# 01-02-2017                  49.548                  41.964       0.752
#
#             dewPoint  humidity  moonPhase  precipIntensity  \
# time
# 01-01-2016    24.940     0.522       0.74          0.00000
# ...

# %%
df_mean.to_csv('darksky_data.csv')
test = pd.read_csv('dakrsky_data.csv')
test.head()
# Out:
#          time  apparentTemperatureHigh  apparentTemperatureLow  \
# 0  01-01-2016                   53.216                  38.102
# 1  01-01-2017                   52.314                  41.958
# 2  01-01-2018                   66.468                  45.264
# 3  01-02-2016                   53.704                  41.892
# 4  01-02-2017                   49.548                  42.752
#
#    apparentTemperatureMax  apparentTemperatureMin  cloudCover  dewPoint  \
# 0                  53.216                  34.786       0.176    24.940
# 1                  52.314                  40.050       0.708    38.928
# 2                  66.468                  42.550       0.308    40.228
# 3                  53.704                  38.374       0.344    30.504
# 4                  49.548                  41.964       0.752    39.374
#
#    humidity  moonPhase  precipIntensity  ...    sunsetTime  temperatureHigh  \
# ...
